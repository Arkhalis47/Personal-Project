# %%
! pip install pygeohash
# Out:
# Requirement already satisfied: pygeohash in /opt/conda/lib/python3.8/site-packages (1.2.0)

# %% [markdown]
# Import stuff

# %%
import json
from pymongo import MongoClient
from pyspark.sql import SparkSession
import pygeohash as pgh
from datetime import datetime
import os
from pprint import pprint
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.3.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0 pyspark-shell'

# %% [markdown]
# Setting up

# %%
host_ip = "YOUR IP"

spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('Streaming Parking Data')
    .getOrCreate()
)

# %%
##subscribe to 3 topics
topic_1 = "Climate"
topic_2 = "Aqua"
topic_3 = "Terra"

# %%
kafka_sdf = (
    spark.readStream
    .format('kafka')
    .option('kafka.bootstrap.servers', f'{host_ip}:9092')
    .option('subscribe', f"{topic_1},{topic_2},{topic_3}")
    .load()
)

# %%
climate_fire_sdf = kafka_sdf.select('value')

# %% [markdown]
# This is the process batch function we will use

# %%
def process_batch(df, epoch_id):
    ##connect to database
    ip_address = "YOUR IP"
    client = MongoClient(f"{ip_address}", 27017)
    db = client.fit3182_assignment_db
    collection = db.overwatch

    climate_data = None
    terra_array = [None] * 5
    aqua_array = [None] * 5
    data_array = df.collect()
    print("#########NEW BATCH #############\n\n")
    
    ##now to store all of them in some temp space first before processing
    look_up_table = {0 : 0, 4 : 1, 9 : 2, 14 : 3, 19 : 4}
    for data in data_array: ##the value is a byte array
        my_data = json.loads(data.value)
        
        if "climate" in my_data:
            climate_data = my_data ##if we have other climate data, we just replace it
            
        elif "aqua" in my_data:
            ##convert into datetime, store into specific index
            new_date = datetime.strptime(my_data["datetime"], "%d/%m/%Y %H:%M:%S")
            if new_date.hour in look_up_table:
                aqua_array[look_up_table.get(new_date.hour)] = my_data
            
        elif "terra" in my_data:
            new_date = datetime.strptime(my_data["datetime"], "%d/%m/%Y %H:%M:%S")
            if new_date.hour in look_up_table:
                terra_array[look_up_table.get(new_date.hour)] = my_data
            
    ##now fo the real processing, we can skip the processing if we don't have climate data
    if climate_data != None:
        ##some initialization
        climate_datetime = datetime.strptime(climate_data["datetime"], "%d/%m/%Y %H:%M:%S")
        climate_data["climate"]["date"] = climate_datetime
        climate_data["climate"]["station"] = "12345"
        climate_data["climate"]["hotspot_data"] = None 
        
        ##get the geohash for climate data
        climate_geohash_p3 = pgh.encode(climate_data["climate"]["latitude"], climate_data["climate"]["longitude"], precision = 3)
        
        ##processing both hotspot data
        for index in range(len(aqua_array)):
            ##skip processing the counterpart as we will not have a match
            if  aqua_array[index] == None: 
                terra_array[index] == None
                
            elif terra_array[index] == None:
                aqua_array[index] == None
                
            else:
                ##get geohash for both the hotspot data
                aqua_lat = aqua_array[index]["aqua"]["latitude"]
                aqua_long = aqua_array[index]["aqua"]["longitude"]
                terra_lat = terra_array[index]["terra"]["latitude"]
                terra_long = terra_array[index]["terra"]["longitude"]
    
                ##short circuit if aqua geohash is not same as climate geohash
                print(f"Aqua Geohash P3: {pgh.encode(aqua_lat, aqua_long, precision = 3)}")
                print(f"Terra Geohash P3: {pgh.encode(terra_lat, terra_long, precision = 3)}")
                print(f"Climate Geohash P3: {climate_geohash_p3}\n\n")
                if pgh.encode(aqua_lat, aqua_long, precision = 3) == climate_geohash_p3 == pgh.encode(terra_lat, terra_long, precision = 3): ##3 way equality
                    
                    ##proceed to check the geohash on precision 5 for both hotspot data
                    print("Match Found, proceed to check on precision 5 on Terra and Aqua\n")
                    aqua_geohash_p5 = pgh.encode(aqua_lat, aqua_long, precision = 5)
                    terra_geohash_p5 = pgh.encode(terra_lat, terra_long, precision = 5)
                    print(f"Aqua Geohash P5: {aqua_geohash_p5}")
                    print(f"Terra Geohash P5: {terra_geohash_p5}")

                    if aqua_geohash_p5 == terra_geohash_p5:
                        ##register as fire event
                        fire_event = {}
                        print(f"Fire occured at Geohash {aqua_geohash_p5}\n")
                        
                        ##initilization of the new fire event
                        fire_event["confidence"] = (aqua_array[index]["aqua"]["confidence"] + terra_array[index]["terra"]["confidence"]) / 2
                        fire_event["latitude"] = aqua_array[index]["aqua"]["latitude"]
                        fire_event["longitude"] = aqua_array[index]["aqua"]["longitude"]
                        fire_event["surface_temperature_celcius"] = (aqua_array[index]["aqua"]["surface_temperature_celcius"] + terra_array[index]["terra"]["surface_temperature_celcius"]) / 2
                        fire_event["date"] = datetime(climate_datetime.year, climate_datetime.month, climate_datetime.day)
                        
                        ##initialization of datetime for this fire event
                        hotspot_datetime = datetime.strptime(aqua_array[index]["datetime"], "%d/%m/%Y %H:%M:%S")
                        fire_event["datetime"] = datetime(climate_datetime.year, climate_datetime.month, climate_datetime.day, hotspot_datetime.hour, hotspot_datetime.minute, hotspot_datetime.second)
                        
                        ##check whether its a natural fire or random fire
                        if climate_data["climate"]["air_temperature_celcius"] > 20 and climate_data["climate"]["GHI_w/m2"] > 180:
                            fire_event["fire_cause"] = "natural"
                        else:
                            fire_event["fire_cause"] = "other"
                        
                        ##throw them into the climate data
                        if climate_data["climate"]["hotspot_data"] != None:
                            climate_data["climate"]["hotspot_data"].append(fire_event) ##add them in if there were other fire event on this day
                        else:
                            climate_data["climate"]["hotspot_data"] = [fire_event] #create a new array
                        
        ##now to send this climate_data into mongodb
        ##take away the latitude and longitude for climate data
        del climate_data["climate"]["latitude"]
        del climate_data["climate"]["longitude"]
        ##use replace instead if you are running this again
        collection.replace_one({"date": climate_data["climate"]["date"]}, climate_data["climate"], upsert = True)
#         collection.insert_one(climate_data["climate"])
        pprint(climate_data)
                    
    print("#########END BATCH #############\n\n")

# %%
writer = (
    climate_fire_sdf.writeStream.format("Console")
    .outputMode('append')
    .trigger(processingTime = "10 seconds")
    .foreachBatch(process_batch)
)

# %%
try:
    query = writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.')
finally:
    query.stop()
# Out:
# #########NEW BATCH #############
#
#
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r32
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 84,
#              'air_temperature_celcius': 9,
#              'date': datetime.datetime(2023, 1, 11, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.0,
#              'precipitation ': ' 0.08G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.08,
#              'relative_humidity': 40.1,
#              'station': '12345',
#              'windspeed_knots': 12.1},
#  'datetime': '11/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1q
# Climate Geohash P3: r1j
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1q
# Climate Geohash P3: r1j
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r32
# Climate Geohash P3: r1j
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1x
# Climate Geohash P3: r1j
#
#
# Aqua Geohash P3: r1j
# Terra Geohash P3: r1h
# Climate Geohash P3: r1j
#
#
# {'climate': {'GHI_w/m2': 128,
#              'air_temperature_celcius': 15,
#              'date': datetime.datetime(2023, 1, 12, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.02G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.02,
#              'relative_humidity': 50.7,
#              'station': '12345',
#              'windspeed_knots': 9.2},
#  'datetime': '12/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1w
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1s
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1j
# Terra Geohash P3: r1k
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# {'climate': {'GHI_w/m2': 114,
#              'air_temperature_celcius': 13,
#              'date': datetime.datetime(2023, 1, 13, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 12.0,
#              'precipitation ': ' 0.01G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.01,
#              'relative_humidity': 47.1,
#              'station': '12345',
#              'windspeed_knots': 8.1},
#  'datetime': '13/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r32
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1h
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 119,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 1, 14, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.12G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.12,
#              'relative_humidity': 50.7,
#              'station': '12345',
#              'windspeed_knots': 8.6},
#  'datetime': '14/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1r
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1t
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1r
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 83,
#              'air_temperature_celcius': 9,
#              'date': datetime.datetime(2023, 1, 15, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.9,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 41.2,
#              'station': '12345',
#              'windspeed_knots': 9.8},
#  'datetime': '15/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1k
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1x
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r30
# Climate Geohash P3: r1q
#
#
# {'climate': {'GHI_w/m2': 156,
#              'air_temperature_celcius': 20,
#              'date': datetime.datetime(2023, 1, 16, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 16.9,
#              'precipitation ': ' 0.08G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.08,
#              'relative_humidity': 60.8,
#              'station': '12345',
#              'windspeed_knots': 10.4},
#  'datetime': '16/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1r
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1j
# Terra Geohash P3: r1u
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 82,
#              'air_temperature_celcius': 9,
#              'date': datetime.datetime(2023, 1, 17, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.9,
#              'precipitation ': ' 0.12G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.12,
#              'relative_humidity': 42.9,
#              'station': '12345',
#              'windspeed_knots': 8.9},
#  'datetime': '17/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1r
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1r
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 118,
#              'air_temperature_celcius': 13,
#              'date': datetime.datetime(2023, 1, 18, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 19.0,
#              'precipitation ': ' 0.04G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.04,
#              'relative_humidity': 42.5,
#              'station': '12345',
#              'windspeed_knots': 14.0},
#  'datetime': '18/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r38
# Terra Geohash P3: r1t
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r32
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1x
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1w
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1n
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 181,
#              'air_temperature_celcius': 20,
#              'date': datetime.datetime(2023, 1, 19, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 43.6,
#              'station': '12345',
#              'windspeed_knots': 10.3},
#  'datetime': '19/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1v
# Terra Geohash P3: r1k
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1x
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1v
# Terra Geohash P3: r1m
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r33
# Climate Geohash P3: r1x
#
#
# {'climate': {'GHI_w/m2': 121,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 1, 20, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 20.0,
#              'precipitation ': ' 0.12G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.12,
#              'relative_humidity': 49.2,
#              'station': '12345',
#              'windspeed_knots': 10.5},
#  'datetime': '20/01/2023 00:00:00'}
# #########END BATCH #############
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1s
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1k
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1k
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1t
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1k
# Climate Geohash P3: r1k
#
#
# {'climate': {'GHI_w/m2': 111,
#              'air_temperature_celcius': 12,
#              'date': datetime.datetime(2023, 1, 21, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 8.9,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 40.4,
#              'station': '12345',
#              'windspeed_knots': 5.9},
#  'datetime': '21/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1u
# Terra Geohash P3: r1q
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1u
# Terra Geohash P3: r33
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1u
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1t
# Climate Geohash P3: r36
#
#
# {'climate': {'GHI_w/m2': 150,
#              'air_temperature_celcius': 18,
#              'date': datetime.datetime(2023, 1, 22, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 14.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 53.0,
#              'station': '12345',
#              'windspeed_knots': 6.6},
#  'datetime': '22/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1n
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1j
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1q
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1q
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 174,
#              'air_temperature_celcius': 23,
#              'date': datetime.datetime(2023, 1, 23, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.9,
#              'precipitation ': ' 0.08G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.08,
#              'relative_humidity': 63.8,
#              'station': '12345',
#              'windspeed_knots': 7.1},
#  'datetime': '23/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1t
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1w
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r38
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r36
#
#
# {'climate': {'GHI_w/m2': 122,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 1, 24, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 14.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 48.5,
#              'station': '12345',
#              'windspeed_knots': 7.3},
#  'datetime': '24/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1r
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r1q
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r1w
# Climate Geohash P3: r1s
#
#
# {'climate': {'GHI_w/m2': 48,
#              'air_temperature_celcius': 5,
#              'date': datetime.datetime(2023, 1, 25, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 11.1,
#              'precipitation ': ' 0.00A',
#              'precipitation_type': 'A',
#              'precipitation_value': 0.0,
#              'relative_humidity': 34.9,
#              'station': '12345',
#              'windspeed_knots': 4.3},
#  'datetime': '25/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1n
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r33
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r36
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1k
# Climate Geohash P3: r36
#
#
# {'climate': {'GHI_w/m2': 161,
#              'air_temperature_celcius': 20,
#              'date': datetime.datetime(2023, 1, 26, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 22.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 57.4,
#              'station': '12345',
#              'windspeed_knots': 10.9},
#  'datetime': '26/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r33
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1w
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r32
# Terra Geohash P3: r1m
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r38
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1r
# Climate Geohash P3: r1k
#
#
# {'climate': {'GHI_w/m2': 72,
#              'air_temperature_celcius': 8,
#              'date': datetime.datetime(2023, 1, 27, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 7.0,
#              'precipitation ': ' 0.01G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.01,
#              'relative_humidity': 44.5,
#              'station': '12345',
#              'windspeed_knots': 4.7},
#  'datetime': '27/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1t
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1r
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1x
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 84,
#              'air_temperature_celcius': 9,
#              'date': datetime.datetime(2023, 1, 28, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 8.9,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 39.0,
#              'station': '12345',
#              'windspeed_knots': 5.6},
#  'datetime': '28/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r33
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r32
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1q
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1x
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1s
# Climate Geohash P3: r1n
#
#
# {'climate': {'GHI_w/m2': 161,
#              'air_temperature_celcius': 19,
#              'date': datetime.datetime(2023, 1, 29, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 20.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 51.5,
#              'station': '12345',
#              'windspeed_knots': 10.2},
#  'datetime': '29/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1u
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1t
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r1k
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 102,
#              'air_temperature_celcius': 11,
#              'date': datetime.datetime(2023, 1, 30, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 26.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 40.5,
#              'station': '12345',
#              'windspeed_knots': 13.4},
#  'datetime': '30/01/2023 00:00:00'}
# #########END BATCH #############
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1k
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1p
# Terra Geohash P3: r1m
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1s
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1u
# Terra Geohash P3: r33
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1q
# Climate Geohash P3: r1s
#
#
# {'climate': {'GHI_w/m2': 90,
#              'air_temperature_celcius': 10,
#              'date': datetime.datetime(2023, 1, 31, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.08G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.08,
#              'relative_humidity': 43.7,
#              'station': '12345',
#              'windspeed_knots': 9.5},
#  'datetime': '31/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1m
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r32
# Terra Geohash P3: r1q
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1k
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r36
# Climate Geohash P3: r1k
#
#
# {'climate': {'GHI_w/m2': 109,
#              'air_temperature_celcius': 12,
#              'date': datetime.datetime(2023, 2, 1, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 19.0,
#              'precipitation ': ' 0.04G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.04,
#              'relative_humidity': 42.8,
#              'station': '12345',
#              'windspeed_knots': 12.1},
#  'datetime': '01/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1u
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1t
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r33
# Climate Geohash P3: r33
#
#
# Match Found, proceed to check on precision 5 on Terra and Aqua
#
# Aqua Geohash P5: r336f
# Terra Geohash P5: r33us
# {'climate': {'GHI_w/m2': 89,
#              'air_temperature_celcius': 10,
#              'date': datetime.datetime(2023, 2, 2, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 7.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 45.9,
#              'station': '12345',
#              'windspeed_knots': 3.2},
#  'datetime': '02/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1w
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1t
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r33
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r1t
#
#
# {'climate': {'GHI_w/m2': 227,
#              'air_temperature_celcius': 28,
#              'date': datetime.datetime(2023, 2, 3, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 16.9,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 56.7,
#              'station': '12345',
#              'windspeed_knots': 9.3},
#  'datetime': '03/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1u
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1r
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r32
# Terra Geohash P3: r36
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 74,
#              'air_temperature_celcius': 8,
#              'date': datetime.datetime(2023, 2, 4, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 16.9,
#              'precipitation ': ' 0.47G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.47,
#              'relative_humidity': 41.0,
#              'station': '12345',
#              'windspeed_knots': 11.0},
#  'datetime': '04/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1k
# Climate Geohash P3: r1k
#
#
# Match Found, proceed to check on precision 5 on Terra and Aqua
#
# Aqua Geohash P5: r1kvs
# Terra Geohash P5: r1k6n
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1q
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1n
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1k
# Climate Geohash P3: r1k
#
#
# {'climate': {'GHI_w/m2': 92,
#              'air_temperature_celcius': 10,
#              'date': datetime.datetime(2023, 2, 5, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 8.9,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 41.4,
#              'station': '12345',
#              'windspeed_knots': 6.9},
#  'datetime': '05/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r1r
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1q
# Climate Geohash P3: r1q
#
#
# Match Found, proceed to check on precision 5 on Terra and Aqua
#
# Aqua Geohash P5: r1q73
# Terra Geohash P5: r1qzx
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# {'climate': {'GHI_w/m2': 223,
#              'air_temperature_celcius': 28,
#              'date': datetime.datetime(2023, 2, 6, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 18.1,
#              'precipitation ': ' 0.04G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.04,
#              'relative_humidity': 58.4,
#              'station': '12345',
#              'windspeed_knots': 11.9},
#  'datetime': '06/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1k
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1k
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1x
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 99,
#              'air_temperature_celcius': 11,
#              'date': datetime.datetime(2023, 2, 7, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 21.0,
#              'precipitation ': ' 0.24G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.24,
#              'relative_humidity': 43.5,
#              'station': '12345',
#              'windspeed_knots': 13.1},
#  'datetime': '07/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1s
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1k
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1j
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1r
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r36
# Climate Geohash P3: r1q
#
#
# {'climate': {'GHI_w/m2': 132,
#              'air_temperature_celcius': 16,
#              'date': datetime.datetime(2023, 2, 8, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 9.9,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 54.9,
#              'station': '12345',
#              'windspeed_knots': 5.9},
#  'datetime': '08/02/2023 00:00:00'}
# #########END BATCH #############
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1w
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1q
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r1s
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r1s
#
#
# {'climate': {'GHI_w/m2': 196,
#              'air_temperature_celcius': 24,
#              'date': datetime.datetime(2023, 2, 9, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 55.5,
#              'station': '12345',
#              'windspeed_knots': 7.9},
#  'datetime': '09/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r38
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1w
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# {'climate': {'GHI_w/m2': 149,
#              'air_temperature_celcius': 18,
#              'date': datetime.datetime(2023, 2, 10, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 11.1,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 53.8,
#              'station': '12345',
#              'windspeed_knots': 6.4},
#  'datetime': '10/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1t
# Climate Geohash P3: r1r
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1n
# Climate Geohash P3: r1r
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1n
# Climate Geohash P3: r1r
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1r
# Climate Geohash P3: r1r
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r1r
#
#
# {'climate': {'GHI_w/m2': 128,
#              'air_temperature_celcius': 15,
#              'date': datetime.datetime(2023, 2, 11, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.9,
#              'precipitation ': ' 0.16G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.16,
#              'relative_humidity': 51.0,
#              'station': '12345',
#              'windspeed_knots': 9.6},
#  'datetime': '11/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r36
# Terra Geohash P3: r1t
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1t
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1n
# Climate Geohash P3: r36
#
#
# {'climate': {'GHI_w/m2': 158,
#              'air_temperature_celcius': 21,
#              'date': datetime.datetime(2023, 2, 12, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.9,
#              'precipitation ': ' 1.26G',
#              'precipitation_type': 'G',
#              'precipitation_value': 1.26,
#              'relative_humidity': 64.5,
#              'station': '12345',
#              'windspeed_knots': 10.6},
#  'datetime': '12/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1t
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1t
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1u
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r32
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 102,
#              'air_temperature_celcius': 11,
#              'date': datetime.datetime(2023, 2, 13, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 8.9,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 40.8,
#              'station': '12345',
#              'windspeed_knots': 6.4},
#  'datetime': '13/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1t
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r32
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1w
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1j
# Climate Geohash P3: r1x
#
#
# {'climate': {'GHI_w/m2': 91,
#              'air_temperature_celcius': 10,
#              'date': datetime.datetime(2023, 2, 14, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 7.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 43.3,
#              'station': '12345',
#              'windspeed_knots': 2.6},
#  'datetime': '14/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1k
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r32
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r32
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1w
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r32
# Climate Geohash P3: r1w
#
#
# {'climate': {'GHI_w/m2': 152,
#              'air_temperature_celcius': 17,
#              'date': datetime.datetime(2023, 2, 15, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 27.0,
#              'precipitation ': ' 0.24G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.24,
#              'relative_humidity': 44.9,
#              'station': '12345',
#              'windspeed_knots': 16.1},
#  'datetime': '15/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1x
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r32
# Terra Geohash P3: r1q
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r32
# Terra Geohash P3: r1t
# Climate Geohash P3: r1t
#
#
# {'climate': {'GHI_w/m2': 128,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 2, 16, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 18.1,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 41.6,
#              'station': '12345',
#              'windspeed_knots': 13.1},
#  'datetime': '16/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1w
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1t
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1q
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1s
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r1t
#
#
# {'climate': {'GHI_w/m2': 150,
#              'air_temperature_celcius': 18,
#              'date': datetime.datetime(2023, 2, 17, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 53.7,
#              'station': '12345',
#              'windspeed_knots': 9.0},
#  'datetime': '17/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1u
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1s
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1q
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# {'climate': {'GHI_w/m2': 119,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 2, 18, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 50.9,
#              'station': '12345',
#              'windspeed_knots': 5.9},
#  'datetime': '18/02/2023 00:00:00'}
# #########END BATCH #############
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1q
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r30
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1x
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1w
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 141,
#              'air_temperature_celcius': 16,
#              'date': datetime.datetime(2023, 2, 19, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 16.9,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 47.0,
#              'station': '12345',
#              'windspeed_knots': 12.0},
#  'datetime': '19/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1t
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r33
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r36
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 122,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 2, 20, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 48.4,
#              'station': '12345',
#              'windspeed_knots': 7.5},
#  'datetime': '20/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1m
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1q
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1m
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r33
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r1n
#
#
# {'climate': {'GHI_w/m2': 161,
#              'air_temperature_celcius': 19,
#              'date': datetime.datetime(2023, 2, 21, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 20.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 51.5,
#              'station': '12345',
#              'windspeed_knots': 10.2},
#  'datetime': '21/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1n
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1k
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r33
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 146,
#              'air_temperature_celcius': 17,
#              'date': datetime.datetime(2023, 2, 22, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 21.0,
#              'precipitation ': ' 0.24G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.24,
#              'relative_humidity': 49.9,
#              'station': '12345',
#              'windspeed_knots': 12.2},
#  'datetime': '22/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1w
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1k
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1r
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r32
# Terra Geohash P3: r1k
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# {'climate': {'GHI_w/m2': 118,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 1, 8, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 52.5,
#              'station': '12345',
#              'windspeed_knots': 7.0},
#  'datetime': '08/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1s
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r39
# Terra Geohash P3: r1x
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1k
# Climate Geohash P3: r1x
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r1x
#
#
# {'climate': {'GHI_w/m2': 133,
#              'air_temperature_celcius': 15,
#              'date': datetime.datetime(2023, 1, 18, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 45.6,
#              'station': '12345',
#              'windspeed_knots': 10.2},
#  'datetime': '18/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1u
# Climate Geohash P3: r32
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1n
# Climate Geohash P3: r32
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1s
# Climate Geohash P3: r32
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1s
# Climate Geohash P3: r32
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1t
# Climate Geohash P3: r32
#
#
# {'climate': {'GHI_w/m2': 163,
#              'air_temperature_celcius': 21,
#              'date': datetime.datetime(2023, 1, 28, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 11.1,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 61.1,
#              'station': '12345',
#              'windspeed_knots': 6.6},
#  'datetime': '28/01/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r38
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1q
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1n
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r38
# Terra Geohash P3: r33
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 119,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 2, 7, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 12.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 51.0,
#              'station': '12345',
#              'windspeed_knots': 9.1},
#  'datetime': '07/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r30
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r36
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1k
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1w
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1k
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 103,
#              'air_temperature_celcius': 12,
#              'date': datetime.datetime(2023, 2, 17, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 8.9,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 49.4,
#              'station': '12345',
#              'windspeed_knots': 4.4},
#  'datetime': '17/02/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1t
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r1q
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1w
# Climate Geohash P3: r1q
#
#
# {'climate': {'GHI_w/m2': 115,
#              'air_temperature_celcius': 13,
#              'date': datetime.datetime(2023, 2, 27, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 12.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 46.2,
#              'station': '12345',
#              'windspeed_knots': 5.6},
#  'datetime': '27/02/2023 00:00:00'}
# #########END BATCH #############
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1n
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1q
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1k
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 80,
#              'air_temperature_celcius': 9,
#              'date': datetime.datetime(2023, 3, 9, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 6.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 45.3,
#              'station': '12345',
#              'windspeed_knots': 2.5},
#  'datetime': '09/03/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1u
# Terra Geohash P3: r1q
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1t
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1t
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r32
# Climate Geohash P3: r36
#
#
# {'climate': {'GHI_w/m2': 139,
#              'air_temperature_celcius': 16,
#              'date': datetime.datetime(2023, 3, 19, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 18.1,
#              'precipitation ': ' 0.01G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.01,
#              'relative_humidity': 48.2,
#              'station': '12345',
#              'windspeed_knots': 9.9},
#  'datetime': '19/03/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r1p
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r1p
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1p
# Climate Geohash P3: r1p
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1x
# Climate Geohash P3: r1p
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r36
# Climate Geohash P3: r1p
#
#
# {'climate': {'GHI_w/m2': 166,
#              'air_temperature_celcius': 21,
#              'date': datetime.datetime(2023, 3, 29, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 21.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 59.5,
#              'station': '12345',
#              'windspeed_knots': 12.4},
#  'datetime': '29/03/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r32
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1r
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1k
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1x
# Climate Geohash P3: r36
#
#
# {'climate': {'GHI_w/m2': 216,
#              'air_temperature_celcius': 26,
#              'date': datetime.datetime(2023, 4, 7, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 53.7,
#              'station': '12345',
#              'windspeed_knots': 8.7},
#  'datetime': '07/04/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1u
# Terra Geohash P3: r1s
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1w
# Climate Geohash P3: r1w
#
#
# Match Found, proceed to check on precision 5 on Terra and Aqua
#
# Aqua Geohash P5: r1wcu
# Terra Geohash P5: r1w4x
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1x
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r1w
# Climate Geohash P3: r1w
#
#
# {'climate': {'GHI_w/m2': 136,
#              'air_temperature_celcius': 17,
#              'date': datetime.datetime(2023, 4, 17, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 19.0,
#              'precipitation ': ' 0.04G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.04,
#              'relative_humidity': 58.1,
#              'station': '12345',
#              'windspeed_knots': 11.7},
#  'datetime': '17/04/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r30
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1u
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 102,
#              'air_temperature_celcius': 11,
#              'date': datetime.datetime(2023, 4, 27, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 26.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 40.5,
#              'station': '12345',
#              'windspeed_knots': 13.4},
#  'datetime': '27/04/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r30
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1n
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r1x
# Terra Geohash P3: r33
# Climate Geohash P3: r30
#
#
# {'climate': {'GHI_w/m2': 150,
#              'air_temperature_celcius': 18,
#              'date': datetime.datetime(2023, 5, 7, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 53.3,
#              'station': '12345',
#              'windspeed_knots': 10.8},
#  'datetime': '07/05/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1w
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1q
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1s
# Climate Geohash P3: r1t
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r1t
#
#
# {'climate': {'GHI_w/m2': 178,
#              'air_temperature_celcius': 22,
#              'date': datetime.datetime(2023, 5, 17, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.0,
#              'precipitation ': ' 0.00G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.0,
#              'relative_humidity': 57.0,
#              'station': '12345',
#              'windspeed_knots': 8.5},
#  'datetime': '17/05/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r38
# Terra Geohash P3: r36
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r1n
# Terra Geohash P3: r1m
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1m
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1q
# Climate Geohash P3: r30
#
#
# Aqua Geohash P3: r36
# Terra Geohash P3: r1n
# Climate Geohash P3: r30
#
#
# {'climate': {'GHI_w/m2': 47,
#              'air_temperature_celcius': 5,
#              'date': datetime.datetime(2023, 5, 27, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 5.1,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 38.6,
#              'station': '12345',
#              'windspeed_knots': 1.8},
#  'datetime': '27/05/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1k
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1m
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1t
# Climate Geohash P3: r1w
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1x
# Climate Geohash P3: r1w
#
#
# {'climate': {'GHI_w/m2': 140,
#              'air_temperature_celcius': 16,
#              'date': datetime.datetime(2023, 6, 6, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 12.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 47.5,
#              'station': '12345',
#              'windspeed_knots': 5.4},
#  'datetime': '06/06/2023 00:00:00'}
# #########END BATCH #############
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1x
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1n
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1s
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 125,
#              'air_temperature_celcius': 14,
#              'date': datetime.datetime(2023, 6, 16, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.9,
#              'precipitation ': ' 0.03G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.03,
#              'relative_humidity': 44.6,
#              'station': '12345',
#              'windspeed_knots': 7.7},
#  'datetime': '16/06/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1x
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r36
# Terra Geohash P3: r1w
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r36
# Terra Geohash P3: r1t
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r1m
# Climate Geohash P3: r1m
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r30
# Climate Geohash P3: r1m
#
#
# {'climate': {'GHI_w/m2': 180,
#              'air_temperature_celcius': 23,
#              'date': datetime.datetime(2023, 6, 26, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 26.0,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 60.6,
#              'station': '12345',
#              'windspeed_knots': 10.1},
#  'datetime': '26/06/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1x
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1t
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1k
# Climate Geohash P3: r33
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r33
#
#
# {'climate': {'GHI_w/m2': 98,
#              'air_temperature_celcius': 11,
#              'date': datetime.datetime(2023, 7, 6, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 16.9,
#              'precipitation ': ' 0.08G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.08,
#              'relative_humidity': 45.3,
#              'station': '12345',
#              'windspeed_knots': 10.6},
#  'datetime': '06/07/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r38
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1k
# Climate Geohash P3: r38
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1m
# Climate Geohash P3: r38
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r30
# Climate Geohash P3: r38
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1n
# Climate Geohash P3: r38
#
#
# {'climate': {'GHI_w/m2': 111,
#              'air_temperature_celcius': 12,
#              'date': datetime.datetime(2023, 7, 16, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 16.9,
#              'precipitation ': ' 0.16G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.16,
#              'relative_humidity': 41.0,
#              'station': '12345',
#              'windspeed_knots': 12.9},
#  'datetime': '16/07/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r1w
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1q
# Terra Geohash P3: r1k
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1n
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1m
# Climate Geohash P3: r1n
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1w
# Climate Geohash P3: r1n
#
#
# {'climate': {'GHI_w/m2': 88,
#              'air_temperature_celcius': 10,
#              'date': datetime.datetime(2023, 7, 25, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 9.9,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 46.8,
#              'station': '12345',
#              'windspeed_knots': 5.3},
#  'datetime': '25/07/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r33
# Terra Geohash P3: r33
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1t
# Terra Geohash P3: r39
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1j
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1r
# Terra Geohash P3: r1t
# Climate Geohash P3: r36
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1x
# Climate Geohash P3: r36
#
#
# {'climate': {'GHI_w/m2': 200,
#              'air_temperature_celcius': 24,
#              'date': datetime.datetime(2023, 8, 4, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 15.9,
#              'precipitation ': ' 0.00I',
#              'precipitation_type': 'I',
#              'precipitation_value': 0.0,
#              'relative_humidity': 53.4,
#              'station': '12345',
#              'windspeed_knots': 9.9},
#  'datetime': '04/08/2023 00:00:00'}
# #########END BATCH #############
#
#
# #########NEW BATCH #############
#
#
# Aqua Geohash P3: r1m
# Terra Geohash P3: r1x
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r30
# Terra Geohash P3: r1m
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1k
# Terra Geohash P3: r1w
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1w
# Terra Geohash P3: r1s
# Climate Geohash P3: r1k
#
#
# Aqua Geohash P3: r1s
# Terra Geohash P3: r1q
# Climate Geohash P3: r1k
#
#
# {'climate': {'GHI_w/m2': 110,
#              'air_temperature_celcius': 13,
#              'date': datetime.datetime(2023, 8, 14, 0, 0),
#              'hotspot_data': None,
#              'max_wind_speed': 13.0,
#              'precipitation ': ' 0.12G',
#              'precipitation_type': 'G',
#              'precipitation_value': 0.12,
#              'relative_humidity': 51.1,
#              'station': '12345',
#              'windspeed_knots': 6.0},
#  'datetime': '14/08/2023 00:00:00'}
# #########END BATCH #############
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/conda/lib/python3.8/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# Interrupted by CTRL-C. Stopping query.
